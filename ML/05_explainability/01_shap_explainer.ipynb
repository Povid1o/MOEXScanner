# %% [markdown]
# # SHAP Explainer
#
# - Вычисление локальных SHAP значений для предсказания по тикеру
# - Визуализация топ-5 факторов (графики, текст)
# - Сохранение объяснений для отчета
#
# Основной блок объяснимости модели ML для пользователя.

# %%
import pandas as pd
import numpy as np
from pathlib import Path

try:
    import shap
    print("✅ SHAP доступен")
    SHAP_AVAILABLE = True
except ImportError:
    print("⚠️ SHAP не установлен. Установите: pip install shap")
    SHAP_AVAILABLE = False

print("✅ Библиотеки загружены")

# %% [markdown]
# ## Вычисление SHAP values
#
# SHAP (SHapley Additive exPlanations) позволяет объяснить вклад каждого признака в прогноз модели.

# %%
if SHAP_AVAILABLE:
    # Здесь должна быть загрузка обученной модели LightGBM
    # Для демонстрации создаем заглушку
    
    print("Для полной реализации SHAP:")
    print("1. Загрузите обученную LightGBM модель")
    print("2. Подготовьте данные для объяснения")
    print("3. Создайте SHAP explainer: explainer = shap.TreeExplainer(model)")
    print("4. Вычислите SHAP values: shap_values = explainer.shap_values(X)")
    print("5. Визуализируйте: shap.summary_plot(shap_values, X)")
    
    # Пример кода для использования:
    # explainer = shap.TreeExplainer(lgb_model)
    # shap_values = explainer.shap_values(X_test)
    # shap.summary_plot(shap_values, X_test, plot_type="bar")
    
else:
    print("SHAP недоступен для объяснения моделей")
