# %% [markdown]
# # Объемные признаки
#
# - Скользящие средние и z-score объема
# - Volume Profile: Point of Control (POC), Value Area (VA), width, position
# - Spike-индексы (резкие всплески)
#
# В этом ноутбуке реализована самая сложная часть - расчёт горизонтального профиля объема по окну.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns   
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

print("✅ Библиотеки загружены")
# Out:
# ✅ Библиотеки загружены

# %% [markdown]
# ## Функции расчета объемных признаков

# %%
def volume_ma(volume, window=20):
    """Скользящее среднее объема"""
    return volume.rolling(window=window).mean()


def volume_zscore(volume, window=60):
    """Z-score объема: нормализованное отклонение от среднего"""
    ma = volume.rolling(window=window).mean()
    std = volume.rolling(window=window).std()
    return (volume - ma) / std


def volume_spike(volume, threshold=2.0, window=20):
    """Индикатор всплеска объема: превышает ли объем порог в std"""
    zscore = volume_zscore(volume, window=window)
    return (zscore > threshold).astype(int)


def calculate_volume_profile(df, window=20, num_bins=50):
    """
    Расчет Volume Profile для скользящего окна
    Возвращает: POC (Point of Control), Value Area High, Value Area Low
    """
    poc_list = []
    va_high_list = []
    va_low_list = []
    
    for i in range(len(df)):
        if i < window:
            poc_list.append(np.nan)
            va_high_list.append(np.nan)
            va_low_list.append(np.nan)
            continue
        
        window_data = df.iloc[i-window:i]
        
        # Создаем ценовые уровни (bins)
        price_min = window_data['low'].min()
        price_max = window_data['high'].max()
        bins = np.linspace(price_min, price_max, num_bins)
        
        # Распределяем объем по ценовым уровням
        volume_by_price = np.zeros(len(bins)-1)
        for _, row in window_data.iterrows():
            # Находим bins, которые пересекаются с [low, high] этого бара
            mask = (bins[:-1] >= row['low']) & (bins[1:] <= row['high'])
            volume_by_price[mask] += row['volume'] / mask.sum() if mask.sum() > 0 else 0
        
        # POC: уровень с максимальным объемом
        poc_idx = volume_by_price.argmax()
        poc = (bins[poc_idx] + bins[poc_idx+1]) / 2
        poc_list.append(poc)
        
        # Value Area: 70% объема вокруг POC
        total_volume = volume_by_price.sum()
        target_volume = total_volume * 0.70
        
        # Расширяем от POC вверх и вниз
        va_volume = volume_by_price[poc_idx]
        va_low_idx = poc_idx
        va_high_idx = poc_idx
        
        while va_volume < target_volume and (va_low_idx > 0 or va_high_idx < len(volume_by_price)-1):
            if va_low_idx > 0:
                va_volume += volume_by_price[va_low_idx-1]
                va_low_idx -= 1
            if va_high_idx < len(volume_by_price)-1 and va_volume < target_volume:
                va_volume += volume_by_price[va_high_idx+1]
                va_high_idx += 1
        
        va_low = bins[va_low_idx]
        va_high = bins[va_high_idx+1]
        
        va_high_list.append(va_high)
        va_low_list.append(va_low)
    
    return pd.Series(poc_list, index=df.index), pd.Series(va_high_list, index=df.index), pd.Series(va_low_list, index=df.index)

print("✅ Функции объема загружены")
# Out:
# ✅ Функции объема загружены

# %% [markdown]
# ## ТЕСТЫ ДЛЯ ОБЪЕМНЫХ ПРИЗНАКОВ

# %% [markdown]
# ### ✅ Тест 1: Анализ распределения и нормальности (Z-score Check)
#
# **Цель:** Проверить, насколько хорошо `volume_zscore` приводит объём к нормальному распределению.
#
# **Что делает:**
# - Строит гистограммы сырого объёма и Z-score
# - Q-Q plots для визуальной проверки нормальности
# - Статистические тесты:
#   - **Shapiro-Wilk Test** (классический тест на нормальность)
#   - **Jarque-Bera Test** (на основе skewness и kurtosis)
#   - **Kolmogorov-Smirnov Test** (сравнение с теоретическим нормальным распределением)
# - Описательная статистика: Mean, Std, Skewness, Kurtosis
#
# **Интерпретация:**
# - `p-value > 0.05`: Не можем отвергнуть гипотезу о нормальности ✅
# - `p-value < 0.05`: Данные НЕ нормальные ⚠️
# - **Важно:** Объём на рынке РЕДКО строго нормален, но Z-score стабилизирует его для ML!

# %%
print("=" * 80)
print("📊 ТЕСТ 1: АНАЛИЗ РАСПРЕДЕЛЕНИЯ И НОРМАЛЬНОСТИ")
print("=" * 80)
print()
print("Цель: Проверить, насколько хорошо volume_zscore приводит объём к нормальному распределению")
print()

# Импорты для статистических тестов
from scipy import stats

# Выбираем тикеры для анализа
test_tickers = ['SBER', 'GAZP', 'LKOH', 'GMKN']
OUTPUT_DIR = Path('data') / 'features'

# Создаём сводную таблицу
normality_results = []

fig, axes = plt.subplots(len(test_tickers), 3, figsize=(18, 4*len(test_tickers)))

for idx, ticker in enumerate(test_tickers):
    # Загружаем данные
    df = pd.read_parquet(OUTPUT_DIR / f"{ticker}_volume_features.parquet")
    
    # Убираем NaN
    raw_volume = df['volume'].dropna()
    zscore_volume = df['volume_zscore'].dropna()
    
    # === 1.1 Гистограммы ===
    ax1, ax2, ax3 = axes[idx] if len(test_tickers) > 1 else axes
    
    # Сырой объём
    ax1.hist(raw_volume, bins=50, alpha=0.7, color='blue', edgecolor='black')
    ax1.set_title(f'{ticker}: Сырой объём', fontsize=12, fontweight='bold')
    ax1.set_xlabel('Объём')
    ax1.set_ylabel('Частота')
    ax1.grid(True, alpha=0.3)
    
    # Z-score объёма
    ax2.hist(zscore_volume, bins=50, alpha=0.7, color='green', edgecolor='black')
    ax2.axvline(0, color='red', linestyle='--', linewidth=2, label='Mean=0')
    ax2.axvline(-1, color='orange', linestyle=':', linewidth=1.5, label='±1σ')
    ax2.axvline(1, color='orange', linestyle=':', linewidth=1.5)
    ax2.axvline(-2, color='purple', linestyle=':', linewidth=1, label='±2σ')
    ax2.axvline(2, color='purple', linestyle=':', linewidth=1)
    ax2.set_title(f'{ticker}: Volume Z-Score (нормализованный)', fontsize=12, fontweight='bold')
    ax2.set_xlabel('Z-Score')
    ax2.set_ylabel('Частота')
    ax2.legend(loc='upper right')
    ax2.grid(True, alpha=0.3)
    
    # Q-Q plot для Z-score
    stats.probplot(zscore_volume, dist="norm", plot=ax3)
    ax3.set_title(f'{ticker}: Q-Q Plot (нормальность Z-Score)', fontsize=12, fontweight='bold')
    ax3.grid(True, alpha=0.3)
    
    # === 1.2 Статистические тесты ===
    
    # Shapiro-Wilk Test (тест на нормальность)
    # H0: данные из нормального распределения
    # p < 0.05 → отвергаем H0 (НЕ нормальные)
    
    # Берём только первые 5000 точек (Shapiro-Wilk ограничение)
    sample_size = min(5000, len(zscore_volume))
    shapiro_stat, shapiro_p = stats.shapiro(zscore_volume.sample(sample_size, random_state=42))
    
    # Jarque-Bera Test (альтернатива Shapiro, использует skewness и kurtosis)
    jb_stat, jb_p = stats.jarque_bera(zscore_volume)
    
    # Kolmogorov-Smirnov Test (сравнение с нормальным распределением)
    ks_stat, ks_p = stats.kstest(zscore_volume, 'norm')
    
    # Описательная статистика
    mean_zscore = zscore_volume.mean()
    std_zscore = zscore_volume.std()
    skew_zscore = zscore_volume.skew()
    kurt_zscore = zscore_volume.kurtosis()
    
    # Сохраняем результаты
    normality_results.append({
        'Тикер': ticker,
        'Mean Z-Score': mean_zscore,
        'Std Z-Score': std_zscore,
        'Skewness': skew_zscore,
        'Kurtosis': kurt_zscore,
        'Shapiro-Wilk p': shapiro_p,
        'Jarque-Bera p': jb_p,
        'KS Test p': ks_p,
        'Нормален?': 'Да' if shapiro_p > 0.05 else 'Нет'
    })

plt.tight_layout()
plt.show()

# Таблица результатов
results_df = pd.DataFrame(normality_results)
print("\n📈 Результаты тестов на нормальность:")
print("=" * 80)
print(results_df.to_string(index=False))
print("=" * 80)

print("\n💡 Интерпретация:")
print("  • Mean Z-Score ≈ 0: центрировано")
print("  • Std Z-Score ≈ 1: масштабировано")
print("  • Skewness ≈ 0: симметричное распределение")
print("  • Kurtosis ≈ 0: нормальная \"толщина\" хвостов (3 = нормальное распределение, избыточный эксцесс = 0)")
print("  • p-value > 0.05: не можем отвергнуть нормальность (хорошо)")
print("  • p-value < 0.05: данные НЕ из нормального распределения")

print("\n⚠️  Объём на фондовом рынке РЕДКО бывает нормальным (fat tails, spikes)!")
print("    Z-score не делает его идеально нормальным, но СТАБИЛИЗИРУЕТ для ML.")
print()
# Out:
# ...
# 📊 ТЕСТ 1: АНАЛИЗ РАСПРЕДЕЛЕНИЯ И НОРМАЛЬНОСТИ
# ...
#
# Цель: Проверить, насколько хорошо volume_zscore приводит объём к нормальному распределению
# 📈 Результаты тестов на нормальность:
# ...
# Тикер  Mean Z-Score  Std Z-Score  Skewness  Kurtosis  Shapiro-Wilk p  Jarque-Bera p    KS Test p Нормален?
#  SBER     -0.009050     1.082258  1.760915  4.886128    1.225381e-30            0.0 2.583619e-14       Нет
#  GAZP      0.035529     1.101497  2.258018  7.322883    6.647627e-36            0.0 3.394962e-18       Нет
#  LKOH     -0.008950     1.031747  1.956005  6.108844    1.753565e-32            0.0 4.049278e-18       Нет
#  GMKN      0.104153     1.160411  1.782421  5.062470    4.568896e-31            0.0 5.453430e-09       Нет
# ...
#
# 💡 Интерпретация:
#   • Mean Z-Score ≈ 0: центрировано
#   • Std Z-Score ≈ 1: масштабировано
#   • Skewness ≈ 0: симметричное распределение
#   • Kurtosis ≈ 0: нормальная "толщина" хвостов (3 = нормальное распределение, избыточный эксцесс = 0)
# ...

# %% [markdown]
# ### Тест 2: Volume Spike Informativeness
# T-test: волатильность после спайков vs обычные дни
# Визуализация bar charts
# Проверка Price-Volume relationship

# %%
print("\n" + "=" * 80)
print("🔥 ТЕСТ 2: ИНФОРМАТИВНОСТЬ VOLUME SPIKES")
print("=" * 80)
print()
print("Цель: Проверить, предшествуют ли спайки объёма изменению волатильности")
print("      (Price-Volume Relationship)")
print()

# Параметры
FORWARD_WINDOW = 5  # Смотрим на волатильность через N дней после спайка

spike_analysis = []

for ticker in test_tickers:
    # Загружаем данные
    df = pd.read_parquet(OUTPUT_DIR / f"{ticker}_volume_features.parquet")
    
    # Убираем NaN
    df = df.dropna(subset=['volume_spike', 'log_return'])
    
    # Расчёт волатильности (если её нет)
    if 'realized_vol_5d' not in df.columns:
        df['realized_vol_5d'] = df['log_return'].rolling(window=5).std() * np.sqrt(252)
    
    # Дни со спайками
    spike_days = df[df['volume_spike'] == 1].copy()
    normal_days = df[df['volume_spike'] == 0].copy()
    
    if len(spike_days) == 0:
        print(f"⚠️  {ticker}: Нет спайков объёма")
        continue
    
    # Средняя волатильность после спайка vs после обычного дня
    spike_days['future_vol'] = spike_days['realized_vol_5d'].shift(-FORWARD_WINDOW)
    normal_days['future_vol'] = normal_days['realized_vol_5d'].shift(-FORWARD_WINDOW)
    
    avg_vol_after_spike = spike_days['future_vol'].mean()
    avg_vol_after_normal = normal_days['future_vol'].mean()
    
    # Средний абсолютный return в день спайка
    avg_return_spike = spike_days['log_return'].abs().mean()
    avg_return_normal = normal_days['log_return'].abs().mean()
    
    # T-test: отличаются ли средние волатильности?
    # H0: средние равны
    t_stat, t_p = stats.ttest_ind(
        spike_days['future_vol'].dropna(),
        normal_days['future_vol'].dropna()
    )
    
    # Процент спайков
    spike_pct = (len(spike_days) / len(df)) * 100
    
    spike_analysis.append({
        'Тикер': ticker,
        'Спайков': len(spike_days),
        '% дней': f'{spike_pct:.1f}%',
        'Vol после спайка': avg_vol_after_spike,
        'Vol обычно': avg_vol_after_normal,
        'Разница Vol': avg_vol_after_spike - avg_vol_after_normal,
        'T-test p': t_p,
        'Информативен?': 'Да' if t_p < 0.05 else 'Нет',
        '|Return| в спайк': avg_return_spike,
        '|Return| обычно': avg_return_normal
    })

# Таблица результатов
spike_df = pd.DataFrame(spike_analysis)
print("📊 Анализ информативности спайков:")
print("=" * 80)
print(spike_df.to_string(index=False))
print("=" * 80)

print("\n💡 Интерпретация:")
print(f"  • Анализируем волатильность через {FORWARD_WINDOW} дней после спайка")
print("  • T-test p < 0.05: спайки ЗНАЧИМО связаны с будущей волатильностью ✅")
print("  • T-test p > 0.05: спайки НЕ предсказывают волатильность ❌")
print("  • Разница Vol > 0: после спайков волатильность РАСТЁТ (ожидаемо)")
print("  • |Return| в спайк > обычно: в дни спайков больше движений цены")

# Визуализация
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# График 1: Волатильность после спайков vs обычных дней
ax = axes[0]
x_pos = np.arange(len(test_tickers))
width = 0.35

vol_spike = spike_df['Vol после спайка'].values
vol_normal = spike_df['Vol обычно'].values

bars1 = ax.bar(x_pos - width/2, vol_spike, width, label='После спайка', color='red', alpha=0.7)
bars2 = ax.bar(x_pos + width/2, vol_normal, width, label='Обычные дни', color='blue', alpha=0.7)

ax.set_xlabel('Тикер', fontsize=12)
ax.set_ylabel(f'Волатильность через {FORWARD_WINDOW}d', fontsize=12)
ax.set_title('Сравнение волатильности: Спайки vs Обычные дни', fontsize=14, fontweight='bold')
ax.set_xticks(x_pos)
ax.set_xticklabels(test_tickers)
ax.legend()
ax.grid(True, alpha=0.3, axis='y')

# График 2: Распределение количества спайков
ax = axes[1]
spike_counts = spike_df['Спайков'].values
colors = ['green' if p < 0.05 else 'red' for p in spike_df['T-test p'].values]

bars = ax.bar(test_tickers, spike_counts, color=colors, alpha=0.7, edgecolor='black')
ax.set_xlabel('Тикер', fontsize=12)
ax.set_ylabel('Количество спайков', fontsize=12)
ax.set_title('Количество volume spikes (зелёный = информативный)', fontsize=14, fontweight='bold')
ax.grid(True, alpha=0.3, axis='y')

# Добавляем легенду
from matplotlib.patches import Patch
legend_elements = [
    Patch(facecolor='green', alpha=0.7, label='p < 0.05 (информативен)'),
    Patch(facecolor='red', alpha=0.7, label='p > 0.05 (не информативен)')
]
ax.legend(handles=legend_elements, loc='upper right')

plt.tight_layout()
plt.show()
print()
# Out:
# ...
# 🔥 ТЕСТ 2: ИНФОРМАТИВНОСТЬ VOLUME SPIKES
# ...
#
# Цель: Проверить, предшествуют ли спайки объёма изменению волатильности
#       (Price-Volume Relationship)
#
# 📊 Анализ информативности спайков:
# ...
# Тикер  Спайков % дней  Vol после спайка  Vol обычно  Разница Vol     T-test p Информативен?  |Return| в спайк  |Return| обычно
#  SBER       76   5.8%          0.364076    0.255738     0.108338 6.475193e-04            Да          0.033778         0.011946
#  GAZP       72   5.5%          0.494994    0.284910     0.210083 1.455679e-08            Да          0.048851         0.013065
#  LKOH       69   5.3%          0.342183    0.242695     0.099489 8.090602e-05            Да          0.031955         0.011709
#  GMKN       76   5.9%          0.344443    0.263861     0.080582 1.162617e-04            Да          0.032657         0.012724
# ...
#
# 💡 Интерпретация:
#   • Анализируем волатильность через 5 дней после спайка
#   • T-test p < 0.05: спайки ЗНАЧИМО связаны с будущей волатильностью ✅
# ...

# %% [markdown]
# ### Тест 3: Correlation Matrix
# - Мультиколлинеарность между признаками
# - Корреляция с log_return
# - Heatmap + bar chart

# %%
# ============================================================================
# ТЕСТ 3: МАТРИЦА КОРРЕЛЯЦИЙ (MULTICOLLINEARITY & TARGET)
# ============================================================================

print("\n" + "=" * 80)
print("🔗 ТЕСТ 3: МАТРИЦА КОРРЕЛЯЦИЙ")
print("=" * 80)
print()
print("Цель: Проверить мультиколлинеарность объёмных признаков и связь с log_return")
print()

# Выбираем один тикер для детального анализа
main_ticker = 'SBER'
df = pd.read_parquet(OUTPUT_DIR / f"{main_ticker}_volume_features.parquet")

# Объёмные признаки для анализа
volume_cols = [
    'volume',
    'volume_ma_20',
    'volume_ma_60',
    'volume_zscore',
    'volume_spike',
    'vp_width',
    'vp_position'
]

# Добавляем target (log_return)
analysis_cols = volume_cols + ['log_return']

# Фильтруем только существующие колонки
analysis_cols = [col for col in analysis_cols if col in df.columns]

# Корреляционная матрица
corr_matrix = df[analysis_cols].corr()

# Визуализация
fig, axes = plt.subplots(1, 2, figsize=(18, 8))

# Heatmap 1: Полная матрица
ax = axes[0]
sns.heatmap(corr_matrix, annot=True, fmt='.3f', cmap='RdYlGn', center=0,
            square=True, linewidths=1, cbar_kws={"shrink": 0.8}, ax=ax,
            vmin=-1, vmax=1)
ax.set_title(f'{main_ticker}: Корреляция объёмных признаков', 
             fontsize=14, fontweight='bold')

# Heatmap 2: Только корреляция с log_return
ax = axes[1]
corr_with_target = corr_matrix['log_return'].drop('log_return').sort_values(ascending=False)

colors = ['green' if x > 0 else 'red' for x in corr_with_target.values]
bars = ax.barh(range(len(corr_with_target)), corr_with_target.values, color=colors, alpha=0.7, edgecolor='black')

ax.set_yticks(range(len(corr_with_target)))
ax.set_yticklabels(corr_with_target.index)
ax.set_xlabel('Корреляция с log_return', fontsize=12)
ax.set_title(f'{main_ticker}: Связь объёмных признаков с доходностью', 
             fontsize=14, fontweight='bold')
ax.axvline(0, color='black', linewidth=1)
ax.grid(True, alpha=0.3, axis='x')

plt.tight_layout()
plt.show()

# Анализ мультиколлинеарности
print("\n📊 Анализ мультиколлинеарности:")
print("=" * 80)

# Высокие корреляции между признаками (исключая target)
volume_only = corr_matrix.loc[volume_cols, volume_cols]
high_corr_pairs = []

for i in range(len(volume_only.columns)):
    for j in range(i+1, len(volume_only.columns)):
        corr_val = volume_only.iloc[i, j]
        if abs(corr_val) > 0.7:  # Порог для высокой корреляции
            high_corr_pairs.append({
                'Feature 1': volume_only.columns[i],
                'Feature 2': volume_only.columns[j],
                'Correlation': corr_val
            })

if high_corr_pairs:
    print("\n⚠️  Высокая корреляция (|r| > 0.7) между признаками:")
    high_corr_df = pd.DataFrame(high_corr_pairs)
    print(high_corr_df.to_string(index=False))
else:
    print("\n✅ Мультиколлинеарность низкая (|r| < 0.7 между всеми признаками)")

# Корреляция с target
print("\n\n📈 Корреляция с log_return:")
print("=" * 80)
print(corr_with_target.to_string())
print("=" * 80)

print("\n💡 Интерпретация:")
print("  • |r| > 0.7: Сильная мультиколлинеарность → можно удалить один из признаков")
print("  • |r| = 0.5-0.7: Умеренная корреляция → оставляем оба (могут дополнять друг друга)")
print("  • |r| < 0.5: Низкая корреляция → признаки независимы ✅")
print("\n  • Корреляция с log_return обычно СЛАБАЯ (объём ≠ направление движения)")
print("  • Объём больше связан с ВОЛАТИЛЬНОСТЬЮ, чем с ДОХОДНОСТЬЮ")
print("  • Volume spike может быть полезен для ML даже при низкой линейной корреляции!")

print("\n\n" + "=" * 80)
print("🎉 ВСЕ ТЕСТЫ ЗАВЕРШЕНЫ")
print("=" * 80)
# Out:
# ...
# 🔗 ТЕСТ 3: МАТРИЦА КОРРЕЛЯЦИЙ
# ...
#
# Цель: Проверить мультиколлинеарность объёмных признаков и связь с log_return
# 📊 Анализ мультиколлинеарности:
# ...
#
# ⚠️  Высокая корреляция (|r| > 0.7) между признаками:
#    Feature 1    Feature 2  Correlation
# volume_ma_20 volume_ma_60     0.764249
# volume_ma_20     vp_width     0.744813
#
#
# 📈 Корреляция с log_return:
# ...
# vp_position      0.349875
# volume_spike    -0.027055
# vp_width        -0.079743
# volume_zscore   -0.080846
# volume_ma_60    -0.088810
# volume_ma_20    -0.108301
# volume          -0.262423
# ...
#
# 💡 Интерпретация:
#   • |r| > 0.7: Сильная мультиколлинеарность → можно удалить один из признаков
#   • |r| = 0.5-0.7: Умеренная корреляция → оставляем оба (могут дополнять друг друга)
#   • |r| < 0.5: Низкая корреляция → признаки независимы ✅
#
#   • Корреляция с log_return обычно СЛАБАЯ (объём ≠ направление движения)
#   • Объём больше связан с ВОЛАТИЛЬНОСТЬЮ, чем с ДОХОДНОСТЬЮ
# ...

# %% [markdown]
# ## Загрузка, расчет и сохранение признаков

# %%
# Получаем текущую рабочую директорию
current_dir = Path.cwd()
print(f"Текущая директория: {current_dir}")

# Строим путь к данным относительно текущей директории
# Если ноутбук в 'ML/02_feature_engineering/', а данные в 'ML/data/processed'
DATA_DIR = current_dir.parent.parent / "ML" / "data" / "processed"
OUTPUT_DIR = Path('data') / 'features'
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
print(f"Путь к данным: {DATA_DIR}")

# Проверяем существование пути
if DATA_DIR.exists():
    print("Директория найдена!")
else:
    print("Директория не найдена, проверьте путь")

# Список всех доступных тикеров включая индекс MOEX
tickers = [
    'AFKS', 'AFLT', 'ALRS', 'BELU', 'BSPB', 'CHMF', 'FIVE', 'GAZP', 'GMKN', 'HYDR',
    'IMOEX',  # Индекс Мосбиржи
    'IRAO', 'LENT', 'LKOH', 'MAGN', 'MGNT', 'MTSS', 'NLMK', 'NVTK', 'OZON',
    'PIKK', 'PLZL', 'ROSN', 'RTKM', 'SBER', 'SNGS', 'TATN', 'TCSG', 'VKCO', 'VTBR', 'YNDX'
]

print(f"✅ Загрузим {len(tickers)} тикеров")
print(f"Тикеры: {tickers}")

# Загружаем все данные в словарь
processed_data = {}
for ticker in tickers:
    try:
        print(f"🔄 Обработка {ticker}...", end=" ")
        
        # 1. Загрузка данных
        input_path = DATA_DIR / f"{ticker}_ohlcv_returns.parquet"
        if not input_path.exists():
            print(f"⚠️ Файл не найден: {input_path}")
            continue
            
        df = pd.read_parquet(input_path)
        
        # 2. Расчет объемных признаков
        # Скользящие средние и Z-score
        df['volume_ma_20'] = volume_ma(df['volume'], window=20)
        df['volume_ma_60'] = volume_ma(df['volume'], window=60)
        df['volume_zscore'] = volume_zscore(df['volume'], window=60)
        
        # Индикатор всплеска объема
        df['volume_spike'] = volume_spike(df['volume'], threshold=2.0, window=20)
        
        # Volume Profile (самая ресурсоемкая часть)
        # Если будет слишком долго, можно временно закомментировать для теста
        df['vp_poc'], df['vp_va_high'], df['vp_va_low'] = calculate_volume_profile(df, window=20, num_bins=50)
        
        # Производные от профиля объема
        df['vp_width'] = df['vp_va_high'] - df['vp_va_low']
        
        # Позиция цены относительно профиля (нормированная)
        # Избегаем деления на ноль, если ширина равна 0
        df['vp_position'] = np.where(
            df['vp_width'] != 0,
            (df['close'] - df['vp_poc']) / df['vp_width'],
            0
        )

        # 3. Сохранение
        output_path = OUTPUT_DIR / f"{ticker}_volume_features.parquet"
        df.to_parquet(output_path, index=False)
        
        processed_data[ticker] = len(df)
        print(f"✅ Готово ({len(df)} строк)")

    except Exception as e:
        print(f"\n❌ Ошибка при обработке {ticker}: {e}")

print("-" * 50)
print(f"🎉 Обработка завершена. Успешно обработано: {len(processed_data)} из {len(tickers)}")
# Out:
# Текущая директория: e:\Python\VolatilityChecker\MOEXScanner\ML\02_feature_engineering
# Путь к данным: e:\Python\VolatilityChecker\MOEXScanner\ML\data\processed
# Директория найдена!
# ✅ Загрузим 31 тикеров
# Тикеры: ['AFKS', 'AFLT', 'ALRS', 'BELU', 'BSPB', 'CHMF', 'FIVE', 'GAZP', 'GMKN', 'HYDR', 'IMOEX', 'IRAO', 'LENT', 'LKOH', 'MAGN', 'MGNT', 'MTSS', 'NLMK', 'NVTK', 'OZON', 'PIKK', 'PLZL', 'ROSN', 'RTKM', 'SBER', 'SNGS', 'TATN', 'TCSG', 'VKCO', 'VTBR', 'YNDX']
# 🔄 Обработка AFKS... ✅ Готово (1301 строк)
# 🔄 Обработка AFLT... ✅ Готово (1301 строк)
# 🔄 Обработка ALRS... ✅ Готово (1301 строк)
# 🔄 Обработка BELU... ✅ Готово (1289 строк)
# 🔄 Обработка BSPB... ✅ Готово (1295 строк)
# 🔄 Обработка CHMF... ✅ Готово (1301 строк)
# 🔄 Обработка FIVE... ✅ Готово (242 строк)
# 🔄 Обработка GAZP... ✅ Готово (1301 строк)
# 🔄 Обработка GMKN... ✅ Готово (1297 строк)
# 🔄 Обработка HYDR... ✅ Готово (1301 строк)
# 🔄 Обработка IMOEX... ✅ Готово (1253 строк)
# 🔄 Обработка IRAO... ✅ Готово (1299 строк)
# ...
